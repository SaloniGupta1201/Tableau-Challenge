# %%
# NYC Citibike Program 2020 - get 2020 January-December and 2021 January tripdata
import pandas as pd
import datetime
import numpy as np
import os

# %%
# Get NYC Citibike tripdata csv files from 201806 to 201808
filepath_jan = os.path.join("Resources" ,"JC-202001-citibike-tripdata.csv")
filepath_feb = os.path.join("Resources" ,"JC-202002-citibike-tripdata.csv")
filepath_mar = os.path.join("Resources" ,"JC-202003-citibike-tripdata.csv")
filepath_apr = os.path.join("Resources" ,"JC-202004-citibike-tripdata.csv")
filepath_may = os.path.join("Resources" ,"JC-202005-citibike-tripdata.csv")
filepath_jun = os.path.join("Resources" ,"JC-202006-citibike-tripdata.csv")
filepath_jul = os.path.join("Resources" ,"JC-202007-citibike-tripdata.csv")
filepath_aug = os.path.join("Resources" ,"JC-202008-citibike-tripdata.csv")
filepath_sep = os.path.join("Resources" ,"JC-202009-citibike-tripdata.csv")
filepath_oct = os.path.join("Resources" ,"JC-202010-citibike-tripdata.csv")
filepath_nov = os.path.join("Resources" ,"JC-202011-citibike-tripdata.csv")
filepath_dec = os.path.join("Resources" ,"JC-202012-citibike-tripdata.csv")
filepath_jan21 = os.path.join("Resources" ,"JC-202101-citibike-tripdata.csv")

nycbike_2020jan = pd.read_csv(filepath_jan)
nycbike_2020feb = pd.read_csv(filepath_feb)
nycbike_2020mar = pd.read_csv(filepath_mar)
nycbike_2020apr = pd.read_csv(filepath_apr)
nycbike_2020may = pd.read_csv(filepath_may)
nycbike_2020jun = pd.read_csv(filepath_jun)
nycbike_2020jul = pd.read_csv(filepath_jul)
nycbike_2020aug = pd.read_csv(filepath_aug)
nycbike_2020sep = pd.read_csv(filepath_sep)
nycbike_2020oct = pd.read_csv(filepath_oct)
nycbike_2020nov = pd.read_csv(filepath_nov)
nycbike_2020dec = pd.read_csv(filepath_dec)
nycbike_2021jan = pd.read_csv(filepath_jan21)

# %%
nycbike_jan_dec = pd.concat([nycbike_2020jan,nycbike_2020feb,nycbike_2020mar,nycbike_2020apr,nycbike_2020may,nycbike_2020jun,
nycbike_2020jul,nycbike_2020aug,nycbike_2020sep,nycbike_2020oct,nycbike_2020nov,nycbike_2020dec,nycbike_2021jan])

# %%
# Output concatenated 2018 July-Aug citibike tripdata to CSV file 
filepath_2020_jan_dec = os.path.join("Resources" ,"JC-2020-2021jan-citibike-tripdata1.csv")
nycbike_jan_dec.to_csv(filepath_2020_jan_dec, index=False)
nycbike_jan_dec.tail(10)
# Out:
#        tripduration                 starttime                  stoptime  \
# 11614           473  2021-01-31 19:59:10.1110  2021-01-31 20:07:03.8480
# 11615           748  2021-01-31 20:01:29.4990  2021-01-31 20:13:57.8940
# 11616           373  2021-01-31 20:01:43.9180  2021-01-31 20:07:57.5030
# 11617           510  2021-01-31 20:03:42.4030  2021-01-31 20:12:12.6890
# 11618           333  2021-01-31 20:13:31.8350  2021-01-31 20:19:05.5830
# 11619          2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620           147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621           660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622           384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623           356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id          start station name  start station latitude  \
# 11614              3220           5 Corners Library               40.734961
# ...

# %%
nycbike_jan_dec.count()
# Out:
# tripduration               348426
# starttime                  348426
# stoptime                   348426
# start station id           348426
# start station name         348426
# start station latitude     348426
# start station longitude    348426
# end station id             348426
# end station name           348426
# end station latitude       348426
# end station longitude      348426
# bikeid                     348426
# usertype                   348426
# birth year                 348426
# gender                     348426
# dtype: int64
